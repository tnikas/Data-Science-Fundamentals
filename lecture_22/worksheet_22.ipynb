# %% [markdown]
# # Worksheet 22
#
# Name: Themistoklis Nikas
#
# UID: U91062110
#
# ### Topics
#
# - Neural Networks
#
# ## Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu
 
#       x[0] --- h1 
#            \ /    \
#             X       output
#            / \    /
#       x[1] --- h2
#
# This is the base model - nothing fancy here

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])
colors = np.hstack([colors] * 20)

# CIRCLE
def generate_circle_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 < 1 or (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 > 1.5, t)))
    Y = np.array([1 if (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 >= 1 else 0 for x in X])
    return X, Y

# LINE
def generate_line_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : x[0] - x[1] < -.5 or x[0] - x[1] > .5, t)))
    Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])
    return X, Y

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# XOR
def generate_xor_data():
    X = np.array([
        [0,0],
        [0,1],
        [1,0],
        [1,1]])
    Y = np.array([x[0]^x[1] for x in X])
    return X, Y

PLOT_HIDDEN_LAYER_2D = False
PLOT_HIDDEN_LAYER_3D = True

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid")) # number of neurons in the hidden layer
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_circle_data(t)
# X, Y = generate_line_data(t)
# X, Y = generate_curve_data(t)
# X, Y = generate_xor_data()

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=1, epochs=2000)

if PLOT_HIDDEN_LAYER_2D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    plt.scatter(layerVals[:,0], layerVals[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
    plt.show()

    # create a mesh to plot in
    h = .02  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - .5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - .5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel()]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=2, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < .5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < .5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=.9)
    ax.set_xlabel("h0")
    ax.set_ylabel("h1")
    plt.show()

if PLOT_HIDDEN_LAYER_3D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(layerVals[:,0], layerVals[:, 1], layerVals[:, 2], color=colors[Y].tolist(), s=100, alpha=.9)
    plt.show()

    # create a mesh to plot in
    h = .1  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - .5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - .5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel(), np.zeros(len(xx.ravel()))]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=3, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < .5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired) # plot in 2D
    ax.axis('off')

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < .5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=.9) # plot in 2D
    plt.show()

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
T = model.predict(X)
T = np.array([0 if x < .5 else 1 for x in T])
T = T.reshape(X[:,0].shape)
ax.scatter(X[:, 0], X[:, 1], color=colors[T].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/2000
# 166/166 [==============================] - 1s 2ms/step - loss: 0.7100
# Epoch 2/2000
2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3469
# Epoch 230/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3447
# Epoch 231/2000
# 166/166 [==============================] - 0s 3ms/step - loss: 0.3425
# Epoch 232/2000
# 166/166 [==============================] - 1s 4ms/step - loss: 0.3401
# Epoch 233/2000
# 166/166 [==============================] - 0s 3ms/step - loss: 0.3383
# Epoch 234/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3358
# Epoch 235/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3342
# Epoch 236/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3321
# Epoch 237/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3298
# Epoch 238/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3278
# Epoch 239/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3254
# Epoch 240/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3238
# Epoch 241/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3216
# Epoch 242/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3195
# Epoch 243/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3175
# Epoch 244/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3154
# Epoch 245/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3135
# Epoch 246/2000
# 166/166 [==============================] - 0s 990us/step - loss: 0.3118
# Epoch 247/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3093
# Epoch 248/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3072
# Epoch 249/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3058
# Epoch 250/2000
# 166/166 [==============================] - 1s 3ms/step - loss: 0.3040
# Epoch 251/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3018
# Epoch 252/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3000
# Epoch 253/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2978
# Epoch 254/2000
# 166/166 [==============================] - 0s 998us/step - loss: 0.2956
# Epoch 255/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2939
# Epoch 256/2000
# 166/166 [==============================] - 0s 998us/step - loss: 0.2919
# Epoch 257/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2898
# Epoch 258/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2880
# Epoch 259/2000
# 166/166 [==============================] - 0s 974us/step - loss: 0.2858
# Epoch 260/2000
# 166/166 [==============================] - 0s 844us/step - loss: 0.2837
# Epoch 261/2000
# 166/166 [==============================] - 0s 796us/step - loss: 0.2820
# Epoch 262/2000
# 166/166 [==============================] - 0s 936us/step - loss: 0.2804
# Epoch 263/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2784
# Epoch 264/2000
# 166/166 [==============================] - 0s 774us/step - loss: 0.2761
# Epoch 265/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2745
# Epoch 266/2000
# 166/166 [==============================] - 0s 900us/step - loss: 0.2724
# Epoch 267/2000
# 166/166 [==============================] - 0s 836us/step - loss: 0.2705
# Epoch 268/2000
# 166/166 [==============================] - 0s 955us/step - loss: 0.2687
# Epoch 269/2000
# 166/166 [==============================] - 0s 913us/step - loss: 0.2669
# Epoch 270/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2656
# Epoch 271/2000
# 166/166 [==============================] - 0s 907us/step - loss: 0.2633
# Epoch 272/2000
# 166/166 [==============================] - 0s 750us/step - loss: 0.2616
# Epoch 273/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2600
# Epoch 274/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2584
# Epoch 275/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2563
# Epoch 276/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2549
# Epoch 277/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2532
# Epoch 278/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2517
# Epoch 279/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2501
# Epoch 280/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2481
# Epoch 281/2000
# 166/166 [==============================] - 0s 884us/step - loss: 0.2467
# Epoch 282/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2451
# Epoch 283/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2433
# Epoch 284/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2420
# Epoch 285/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2405
# Epoch 286/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2388
# Epoch 287/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2375
# Epoch 288/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2360
# Epoch 289/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2345
# Epoch 290/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2332
# Epoch 291/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2317
# Epoch 292/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2303
# Epoch 293/2000
# 166/166 [==============================] - 0s 864us/step - loss: 0.2293
# Epoch 294/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2277
# Epoch 295/2000
# 166/166 [==============================] - 0s 987us/step - loss: 0.2264
# Epoch 296/2000
# 166/166 [==============================] - 0s 906us/step - loss: 0.2250
# Epoch 297/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2240
# Epoch 298/2000
# 166/166 [==============================] - 0s 943us/step - loss: 0.2227
# Epoch 299/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2213
# Epoch 300/2000
# 166/166 [==============================] - 0s 871us/step - loss: 0.2202
# Epoch 301/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2188
# Epoch 302/2000
# 166/166 [==============================] - 0s 884us/step - loss: 0.2176
# Epoch 303/2000
# 166/166 [==============================] - 0s 835us/step - loss: 0.2162
# Epoch 304/2000
# 166/166 [==============================] - 0s 944us/step - loss: 0.2154
# Epoch 305/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2136
# Epoch 306/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2132
# Epoch 307/2000
# 166/166 [==============================] - 0s 791us/step - loss: 0.2120
# Epoch 308/2000
# 166/166 [==============================] - 0s 745us/step - loss: 0.2106
# Epoch 309/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2096
# Epoch 310/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2085
# Epoch 311/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2076
# Epoch 312/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.2065
# Epoch 313/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2053
# Epoch 314/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2040
# Epoch 315/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2038
# Epoch 316/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2024
# Epoch 317/2000
# 166/166 [==============================] - 0s 930us/step - loss: 0.2013
# Epoch 318/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2002
# Epoch 319/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1990
# Epoch 320/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1979
# Epoch 321/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1971
# Epoch 322/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1959
# Epoch 323/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1950
# Epoch 324/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1940
# Epoch 325/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1931
# Epoch 326/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1919
# Epoch 327/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1909
# Epoch 328/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1899
# Epoch 329/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1890
# Epoch 330/2000
# 166/166 [==============================] - 0s 998us/step - loss: 0.1881
# Epoch 331/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1870
# Epoch 332/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1859
# Epoch 333/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1852
# Epoch 334/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1840
# Epoch 335/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1832
# Epoch 336/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1823
# Epoch 337/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1813
# Epoch 338/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1804
# Epoch 339/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1795
# Epoch 340/2000
# 166/166 [==============================] - 0s 958us/step - loss: 0.1785
# Epoch 341/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1780
# Epoch 342/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1768
# Epoch 343/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1759
# Epoch 344/2000
# 166/166 [==============================] - 0s 915us/step - loss: 0.1749
# Epoch 345/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1740
# Epoch 346/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1733
# Epoch 347/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1723
# Epoch 348/2000
# 166/166 [==============================] - 0s 938us/step - loss: 0.1715
# Epoch 349/2000
# 166/166 [==============================] - 0s 999us/step - loss: 0.1708
# Epoch 350/2000
# 166/166 [==============================] - 0s 966us/step - loss: 0.1696
# Epoch 351/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1687
# Epoch 352/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1684
# Epoch 353/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1675
# Epoch 354/2000
# 166/166 [==============================] - 0s 961us/step - loss: 0.1667
# Epoch 355/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1657
# Epoch 356/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1649
# Epoch 357/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1644
# Epoch 358/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1632
# Epoch 359/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1627
# Epoch 360/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1619
# Epoch 361/2000
# 166/166 [==============================] - 0s 939us/step - loss: 0.1611
# Epoch 362/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1607
# Epoch 363/2000
# 166/166 [==============================] - 0s 953us/step - loss: 0.1596
# Epoch 364/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1591
# Epoch 365/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1584
# Epoch 366/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1571
# Epoch 367/2000
# 166/166 [==============================] - 0s 952us/step - loss: 0.1571
# Epoch 368/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1563
# Epoch 369/2000
# 166/166 [==============================] - 0s 944us/step - loss: 0.1554
# Epoch 370/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1545
# Epoch 371/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1544
# Epoch 372/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1534
# Epoch 373/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1528
# Epoch 374/2000
# 166/166 [==============================] - 0s 932us/step - loss: 0.1521
# Epoch 375/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1512
# Epoch 376/2000
# 166/166 [==============================] - 0s 956us/step - loss: 0.1513
# Epoch 377/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1502
# Epoch 378/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1496
# Epoch 379/2000
# 166/166 [==============================] - 0s 967us/step - loss: 0.1485
# Epoch 380/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1480
# Epoch 381/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1475
# Epoch 382/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1468
# Epoch 383/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1462
# Epoch 384/2000
# 166/166 [==============================] - 0s 959us/step - loss: 0.1455
# Epoch 385/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1445
# Epoch 386/2000
# 166/166 [==============================] - 0s 963us/step - loss: 0.1443
# Epoch 387/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1439
# Epoch 388/2000
# 166/166 [==============================] - 0s 998us/step - loss: 0.1430
# Epoch 389/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1423
# Epoch 390/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1417
# Epoch 391/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1412
# Epoch 392/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1404
# Epoch 393/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1396
# Epoch 394/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1393
# Epoch 395/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1384
# Epoch 396/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1380
# Epoch 397/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1372
# Epoch 398/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1366
# Epoch 399/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1363
# Epoch 400/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1358
# Epoch 401/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1352
# Epoch 402/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1345
# Epoch 403/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1340
# Epoch 404/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1332
# Epoch 405/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1328
# Epoch 406/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1323
# Epoch 407/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1315
# Epoch 408/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1311
# Epoch 409/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1304
# Epoch 410/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1299
# Epoch 411/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1293
# Epoch 412/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1288
# Epoch 413/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1283
# Epoch 414/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1280
# Epoch 415/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1273
# Epoch 416/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1268
# Epoch 417/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1262
# Epoch 418/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1256
# Epoch 419/2000
# 166/166 [==============================] - 0s 967us/step - loss: 0.1255
# Epoch 420/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1250
# Epoch 421/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1244
# Epoch 422/2000
# 166/166 [==============================] - 0s 977us/step - loss: 0.1236
# Epoch 423/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1233
# Epoch 424/2000
# 166/166 [==============================] - 0s 961us/step - loss: 0.1232
# Epoch 425/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1223
# Epoch 426/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1220
# Epoch 427/2000
# 166/166 [==============================] - 0s 936us/step - loss: 0.1217
# Epoch 428/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1209
# Epoch 429/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1208
# Epoch 430/2000
# 166/166 [==============================] - 0s 929us/step - loss: 0.1201
# Epoch 431/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1201
# Epoch 432/2000
# 166/166 [==============================] - 0s 931us/step - loss: 0.1197
# Epoch 433/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1192
# Epoch 434/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1187
# Epoch 435/2000
# 166/166 [==============================] - 0s 968us/step - loss: 0.1181
# Epoch 436/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1175
# Epoch 437/2000
# 166/166 [==============================] - 0s 996us/step - loss: 0.1170
# Epoch 438/2000
# 166/166 [==============================] - 0s 945us/step - loss: 0.1166
# Epoch 439/2000
# 166/166 [==============================] - 0s 994us/step - loss: 0.1161
# Epoch 440/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1157
# Epoch 441/2000
# 166/166 [==============================] - 0s 945us/step - loss: 0.1154
# Epoch 442/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1147
# Epoch 443/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1143
# Epoch 444/2000
# 166/166 [==============================] - 0s 952us/step - loss: 0.1141
# Epoch 445/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1139
# Epoch 446/2000
# 166/166 [==============================] - 0s 996us/step - loss: 0.1130
# Epoch 447/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1127
# Epoch 448/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1126
# Epoch 449/2000
# 166/166 [==============================] - 0s 955us/step - loss: 0.1119
# Epoch 450/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1116
# Epoch 451/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1114
# Epoch 452/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1108
# Epoch 453/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1102
# Epoch 454/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1100
# Epoch 455/2000
# 166/166 [==============================] - 0s 990us/step - loss: 0.1097
# Epoch 456/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1092
# Epoch 457/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1086
# Epoch 458/2000
# 166/166 [==============================] - 0s 992us/step - loss: 0.1083
# Epoch 459/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1079
# Epoch 460/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1075
# Epoch 461/2000
# 166/166 [==============================] - 0s 991us/step - loss: 0.1072
# Epoch 462/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1067
# Epoch 463/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1066
# Epoch 464/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1063
# Epoch 465/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1058
# Epoch 466/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1050
# Epoch 467/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1050
# Epoch 468/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1046
# Epoch 469/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1041
# Epoch 470/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1043
# Epoch 471/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1042
# Epoch 472/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1035
# Epoch 473/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1033
# Epoch 474/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1027
# Epoch 475/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1024
# Epoch 476/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1019
# Epoch 477/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1017
# Epoch 478/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1014
# Epoch 479/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1008
# Epoch 480/2000
# 166/166 [==============================] - 0s 972us/step - loss: 0.1004
# Epoch 481/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1003
# Epoch 482/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0997
# Epoch 483/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0993
# Epoch 484/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0991
# Epoch 485/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0984
# Epoch 486/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0986
# Epoch 487/2000
# 166/166 [==============================] - 0s 987us/step - loss: 0.0979
# Epoch 488/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0983
# Epoch 489/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0978
# Epoch 490/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0974
# Epoch 491/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0969
# Epoch 492/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0971
# Epoch 493/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0966
# Epoch 494/2000
# 166/166 [==============================] - 0s 970us/step - loss: 0.0964
# Epoch 495/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0960
# Epoch 496/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0954
# Epoch 497/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0953
# Epoch 498/2000
# 166/166 [==============================] - 0s 995us/step - loss: 0.0952
# Epoch 499/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0943
# Epoch 500/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0944
# Epoch 501/2000
# 166/166 [==============================] - 0s 959us/step - loss: 0.0937
# Epoch 502/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0936
# Epoch 503/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0933
# Epoch 504/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0927
# Epoch 505/2000
# 166/166 [==============================] - 0s 960us/step - loss: 0.0924
# Epoch 506/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0923
# Epoch 507/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0919
# Epoch 508/2000
# 166/166 [==============================] - 0s 976us/step - loss: 0.0919
# Epoch 509/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0915
# Epoch 510/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0913
# Epoch 511/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0909
# Epoch 512/2000
# 166/166 [==============================] - 0s 970us/step - loss: 0.0905
# Epoch 513/2000
# 166/166 [==============================] - 0s 963us/step - loss: 0.0904
# Epoch 514/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0900
# Epoch 515/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0897
# Epoch 516/2000
# 166/166 [==============================] - 0s 933us/step - loss: 0.0893
# Epoch 517/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0892
# Epoch 518/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0889
# Epoch 519/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0884
# Epoch 520/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0884
# Epoch 521/2000
# 166/166 [==============================] - 0s 972us/step - loss: 0.0879
# Epoch 522/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0880
# Epoch 523/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0873
# Epoch 524/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0875
# Epoch 525/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0871
# Epoch 526/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0871
# Epoch 527/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0865
# Epoch 528/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0863
# Epoch 529/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0860
# Epoch 530/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0859
# Epoch 531/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0860
# Epoch 532/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0854
# Epoch 533/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0853
# Epoch 534/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0851
# Epoch 535/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0848
# Epoch 536/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0845
# Epoch 537/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0842
# Epoch 538/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0840
# Epoch 539/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0838
# Epoch 540/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0837
# Epoch 541/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0836
# Epoch 542/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0832
# Epoch 543/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0829
# Epoch 544/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0827
# Epoch 545/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0825
# Epoch 546/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0825
# Epoch 547/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0822
# Epoch 548/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0815
# Epoch 549/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0818
# Epoch 550/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0812
# Epoch 551/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0814
# Epoch 552/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0810
# Epoch 553/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0809
# Epoch 554/2000
# 166/166 [==============================] - 0s 1000us/step - loss: 0.0806
# Epoch 555/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0805
# Epoch 556/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0800
# Epoch 557/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.
2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 1926/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 1927/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1928/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0276
# Epoch 1929/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0276
# Epoch 1930/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1931/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0276
# Epoch 1932/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1933/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1934/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1935/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0272
# Epoch 1936/2000
# 166/166 [==============================] - 0s 945us/step - loss: 0.0273
# Epoch 1937/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 1938/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 1939/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 1940/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0270
# Epoch 1941/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 1942/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 1943/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0270
# Epoch 1944/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0270
# Epoch 1945/2000
# 166/166 [==============================] - 0s 991us/step - loss: 0.0271
# Epoch 1946/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1947/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1948/2000
# 166/166 [==============================] - 0s 997us/step - loss: 0.0273
# Epoch 1949/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 1950/2000
# 166/166 [==============================] - 0s 996us/step - loss: 0.0275
# Epoch 1951/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 1952/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 1953/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0276
# Epoch 1954/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0275
# Epoch 1955/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0276
# Epoch 1956/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1957/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1958/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 1959/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0275
# Epoch 1960/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1961/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0272
# Epoch 1962/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0278
# Epoch 1963/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0275
# Epoch 1964/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 1965/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1966/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1967/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1968/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 1969/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 1970/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 1971/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0276
# Epoch 1972/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0276
# Epoch 1973/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1974/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0275
# Epoch 1975/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1976/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0271
# Epoch 1977/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1978/2000
# 166/166 [==============================] - 0s 987us/step - loss: 0.0277
# Epoch 1979/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1980/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 1981/2000
# 166/166 [==============================] - 0s 990us/step - loss: 0.0273
# Epoch 1982/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0276
# Epoch 1983/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 1984/2000
# 166/166 [==============================] - 0s 997us/step - loss: 0.0274
# Epoch 1985/2000
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0275
# Epoch 1986/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0275
# Epoch 1987/2000
# 166/166 [==============================] - 0s 961us/step - loss: 0.0273
# Epoch 1988/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1989/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 1990/2000
# 166/166 [==============================] - 0s 989us/step - loss: 0.0273
# Epoch 1991/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1992/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 1993/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1994/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0275
# Epoch 1995/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 1996/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 1997/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# Epoch 1998/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0270
# Epoch 1999/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0271
# Epoch 2000/2000
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0273
# {'name': 'dense_20', 'trainable': True, 'dtype': 'float32', 'batch_input_shape': (None, 2), 'units': 3, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None} [array([[ 1.2870991, -5.2828326, -2.798104 ],
#        [-4.62422  ,  1.3708378, -2.153395 ]], dtype=float32), array([-4.6216183, -3.9994624,  2.759085 ], dtype=float32)]
# 20/20 [==============================] - 0s 838us/step
# 6/6 [==============================] - 0s 1ms/step
# 3865/3865 [==============================] - 3s 860us/step
# 6/6 [==============================] - 0s 10ms/step
